# %% [markdown]
# # EPOS S&Op Planner

# %% [markdown]
# Some description

# %% [markdown]
# ## 1. Begin S&Op Planning Session

# %%
# we begin by creating the authentication to sharepoint
from shareplum import Site
from shareplum import Office365
from shareplum.site import Version
import requests
from requests_negotiate_sspi import HttpNegotiateAuth
import getpass

username1=getpass.getuser()+"@eposaudio.com"
username2=getpass.getuser()+"@senncom.com"
password=getpass.getpass(prompt='Password: ', stream=None)

try:
    authcookie = Office365('https://demant.sharepoint.com', username=username1, password=password).GetCookies()
except:
    authcookie = Office365('https://demant.sharepoint.com', username=username2, password=password).GetCookies()
# Out:
# Password: ········

# %%
import pandas as pd

# we now get the data from the sharepoint forecast site
site = Site('https://demant.sharepoint.com/sites/ProjectForecasts/', version=Version.v2016, authcookie=authcookie)
folder = site.Folder('Shared Documents/MP Forecasts')

resp = folder.get_file('Production Forecast.xlsx')

df_mpFC = pd.read_excel(resp, header = 3)

df_mpFC
# Out:
#                Vendor name  Vendor code  Lead time      SKU  \
# 0                     3NOD       1152.0       90.0  1000895
# 1             Bright Trend       1078.0       60.0  1000434
# 2             Bright Trend       1078.0       60.0  1000712
# 3             Bright Trend       1078.0       60.0  1000713
# 4             Bright Trend       1078.0       60.0  1000714
# ..                     ...          ...        ...      ...
# 659  Active SKUs not FC-ed          NaN        NaN   508375
# 660  Active SKUs not FC-ed          NaN        NaN   508376
# 661  Active SKUs not FC-ed          NaN        NaN   508377
# 662  Active SKUs not FC-ed          NaN        NaN   521836
# 663  Active SKUs not FC-ed          NaN        NaN   550572
#
#                 Description  2021-08-01 00:00:00  2021-09-01 00:00:00  \
# 0          EXPAND CAPTURE 5                  NaN                  NaN
# 1                    PCV 05                  NaN                  0.0
# ...

# %%
# %load_ext watermark

# %watermark -v -m -p requests,getpass,pandas

print(" ")
# %watermark -u -n -t -z
# Out:
# Python implementation: CPython
# Python version       : 3.7.6
# IPython version      : 7.12.0
#
# requests: 2.22.0
# getpass : unknown
# pandas  : 1.0.1
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 94 Stepping 3, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit
#
#
# Last updated: Fri Jul 23 2021 12:32:53GMT Daylight Time
